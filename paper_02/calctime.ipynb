# %%
"""
max_iter = 5000, num_ants = 200

sd = 2, time = 3分7.769秒 = 187.769
sd = 3, time = 0分3.136秒 = 3.136
sd = 4, time = 2分15.774秒 = 135.774
sd = 7, elapsed = 171.5986356070007, time = 2分51.599秒
sd = 8, elapsed = 4.193880746999639, time = 0分4.194秒
sd = 9, elapsed = 151.67865423799958, time = 2分31.679秒
sd = 10, elapsed = 3.804790815999695, time = 0分3.805秒
sd = 11, elapsed = 158.56487741900037, time = 2分38.565秒
sd = 12, elapsed = 188.70283670200024, time = 3分8.703秒
sd = 13, elapsed = 190.4075324180003, time = 3分10.408秒
sd = 14, elapsed = 240.7620356080006, time = 4分0.762秒
sd = 15, elapsed = 3.892623072999413, time = 0分3.893秒
sd = 16, elapsed = 185.42606068999976, time = 3分5.426秒

sd = 17, error 
sd = 18, error 
sd = 19, error
"""

# %%
import numpy as np

elapsed_times = np.array([
    187.769, 
    3.136,
    135.774,
    171.5986356070007,
    4.193880746999639,
    151.67865423799958,
    3.804790815999695,
    158.56487741900037,
    188.70283670200024,
    190.4075324180003,
    240.7620356080006,
    3.892623072999413,
    185.42606068999976,
])

# %%
average_time = elapsed_times.mean()
print(f"average_time = {average_time}")

# %%
"""
max_iter = 100, num_ants = 30

sd = 0, elapsed = 0.9759885769999528
sd = 1, elapsed = 1.0755031179996877
sd = 2, elapsed = 0.825506970000788
sd = 3, elapsed = 0.8447510049991251
sd = 4, elapsed = 1.1723339410000335
"""

# %%
elapsed_times = np.array([
    0.9759885769999528,
    1.0755031179996877,
    0.825506970000788,
    0.8447510049991251,
    1.1723339410000335,
])

average_time = elapsed_times.mean()
print(f"average_time = {average_time}")

# %%
"""
max_iter = 1000, num_ants = 100

sd = 0, elapsed = 26.166590853001253
sd = 1, elapsed = 14.889315094000267
sd = 2, elapsed = 16.689389704999485
sd = 3, elapsed = 16.0087385730003
sd = 4, elapsed = 18.576983496999674
"""

# %%
elapsed_times = np.array([
    26.166590853001253,
    14.889315094000267,
    16.689389704999485,
    16.0087385730003,
    18.576983496999674,
])


average_time = elapsed_times.mean()
print(f"average_time = {average_time}")
